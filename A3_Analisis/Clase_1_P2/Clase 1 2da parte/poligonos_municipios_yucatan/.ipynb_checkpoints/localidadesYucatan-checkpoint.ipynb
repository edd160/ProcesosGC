# %%
# !pip install earthpy
# Out:
# ...
#   Obtaining dependency information for earthpy from https://files.pythonhosted.org/packages/a7/72/98c78371de0ffd281d89f7da85bb2001aa6ce9820fabbfd2adfee99e1935/earthpy-0.9.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/90/37/08e416c9915dcf7d53deb0fbdb702266902c584617dfa6e6c84fb2fc6ee3/geopandas-0.14.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for rasterio from https://files.pythonhosted.org/packages/58/53/0cbe275c9240f0a369f4293c80bd62ec61e0802424a549bdda170a12f714/rasterio-1.3.9-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/62/50/cc0cbc48d4f11899611edfb23a99d9d43101d3d28f2ef90a5506782cae84/fiona-1.9.5-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 662.1 kB/s eta 0:00:00 0:00:01
# ...

# %%
import geopandas as gpd
import pandas as pd
import earthpy as et
import shapely

# %%
mapa = gpd.read_file('Basemap_municipios.shp')

# %%
mapa.head()
# Out:
#    OID CVEGEO CVE_ENT  NOM_ENT CVE_MUN        NOMGEO  \
# 0    1  31060      31  YUCATAN     060  QUINTANA ROO
# 1    2  31066      31  YUCATAN     066   SANTA ELENA
# 2    3  31023      31  YUCATAN     023      CHOCHOLA
# 3    4  31071      31  YUCATAN     071        SUDZAL
# 4    5  31047      31  YUCATAN     047          MANI
#
#                                             geometry
# 0  POLYGON ((3881958.812 1054187.020, 3882052.862...
# 1  POLYGON ((3787619.409 983688.235, 3787851.159 ...
# 2  POLYGON ((3757609.268 1032695.941, 3757691.451...
# 3  POLYGON ((3851883.871 1048691.213, 3851887.385...
# 4  POLYGON ((3813669.199 997547.367, 3813692.552 ...

# %%
len(mapa)

# %%
mapa.plot()
# Out:
# <Axes: >
