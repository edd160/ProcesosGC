# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
from urllib.request import Request, urlopen
import pandas as pd
from geopy.geocoders import Nominatim
import time

# %%
parquesFile = urllib.request.urlopen('https://www.timeoutmexico.mx/ciudad-de-mexico/que-hacer/top-10-parques-en-el-df')
parquesHtml = parquesFile.read()
parquesFile.close()

# %%
lista_parques = []

# %%
soup = BeautifulSoup(parquesHtml)
parquesAll = soup.find_all('img')
for links in parquesAll:
  nombre_parque = links.get('title')
  if nombre_parque:
    lista_parques.append(nombre_parque)

# %%
lista_parques
# Out:
# ['Parque Masayoshi Ohira',
#  'Anfiteatro Parque La Mexicana',
#  'Parque Cuitláhuac',
#  'Parque La Mexicana',
#  'Parque Cuitláhuac',
#  'Parque Masayoshi Ohira',
#  'Parque Luis G. Urbina (Parque Hundido)',
#  'Parque Tezozómoc',
#  'Parque Rufino Tamayo',
#  'Parque Lira',
#  'Parque México',
#  'Parque Bicentenario',
#  'Parque de los Venados',
#  'Parque Lincoln',
#  'Parque de los Dinamos',
#  'Parque Alameda Nápoles',
#  'Parque La Tapatía']

# %%
geolocator = Nominatim(user_agent='cctmexico')
df = pd.DataFrame({'nombre':lista_parques})

# %%
df
# Out:
#                                     nombre
# 0                   Parque Masayoshi Ohira
# 1            Anfiteatro Parque La Mexicana
# 2                        Parque Cuitláhuac
# 3                       Parque La Mexicana
# 4                        Parque Cuitláhuac
# 5                   Parque Masayoshi Ohira
# 6   Parque Luis G. Urbina (Parque Hundido)
# 7                         Parque Tezozómoc
# 8                     Parque Rufino Tamayo
# 9                              Parque Lira
# 10                           Parque México
# 11                     Parque Bicentenario
# 12                   Parque de los Venados
# 13                          Parque Lincoln
# 14                   Parque de los Dinamos
# 15                  Parque Alameda Nápoles
# 16                       Parque La Tapatía

# %%
start = time.time()

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

df['direccion'] = df['nombre'].apply(geocode)

end = time.time()
elapsed = end-start
print(str(elapsed)+"seconds")
# Out:
# 16.263418436050415seconds

# %%
df
# Out:
#                                     nombre  \
# 0                   Parque Masayoshi Ohira
# 1            Anfiteatro Parque La Mexicana
# 2                        Parque Cuitláhuac
# 3                       Parque La Mexicana
# 4                        Parque Cuitláhuac
# 5                   Parque Masayoshi Ohira
# 6   Parque Luis G. Urbina (Parque Hundido)
# 7                         Parque Tezozómoc
# 8                     Parque Rufino Tamayo
# 9                              Parque Lira
# 10                           Parque México
# 11                     Parque Bicentenario
# 12                   Parque de los Venados
# 13                          Parque Lincoln
# 14                   Parque de los Dinamos
# 15                  Parque Alameda Nápoles
# 16                       Parque La Tapatía
#
#                                             direccion
# 0   (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 1                                                None
# 2   (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 3   (La Mexicana, Cuajimalpa de Morelos, Ciudad de...
# 4   (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 5   (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 6   (Parque Luis G. Urbina (Parque Hundido), Benit...
# 7   (Parque Tezozómoc, Azcapotzalco, Ciudad de Méx...
# 8   (Parque Rufino Tamayo, San Pedro Garza García,...
# 9   (Parque Lira, Miguel Hidalgo, Ciudad de México...
# 10  (Parque México, Cuauhtémoc, Ciudad de México, ...
# 11  (Parque Bicentenario, Talca, Provincia de Talc...
# 12  (Parque de los Venados, Avenida Municipio Libr...
# 13  (Parque Lincoln, Colonia Polanco Chapultepec, ...
# 14                                               None
# 15  (La Napoles, Calle 80 Sur, Getsemaní, UPZs de ...
# 16  (Zona de Juegos Infantiles "La Tapatía", Colon...

# %%
df = df.dropna()
df
# Out:
#                                     nombre  \
# 0                   Parque Masayoshi Ohira
# 2                        Parque Cuitláhuac
# 3                       Parque La Mexicana
# 4                        Parque Cuitláhuac
# 5                   Parque Masayoshi Ohira
# 6   Parque Luis G. Urbina (Parque Hundido)
# 7                         Parque Tezozómoc
# 8                     Parque Rufino Tamayo
# 9                              Parque Lira
# 10                           Parque México
# 11                     Parque Bicentenario
# 12                   Parque de los Venados
# 13                          Parque Lincoln
# 15                  Parque Alameda Nápoles
# 16                       Parque La Tapatía
#
#                                             direccion
# 0   (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 2   (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 3   (La Mexicana, Cuajimalpa de Morelos, Ciudad de...
# 4   (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 5   (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 6   (Parque Luis G. Urbina (Parque Hundido), Benit...
# 7   (Parque Tezozómoc, Azcapotzalco, Ciudad de Méx...
# 8   (Parque Rufino Tamayo, San Pedro Garza García,...
# 9   (Parque Lira, Miguel Hidalgo, Ciudad de México...
# 10  (Parque México, Cuauhtémoc, Ciudad de México, ...
# 11  (Parque Bicentenario, Talca, Provincia de Talc...
# 12  (Parque de los Venados, Avenida Municipio Libr...
# 13  (Parque Lincoln, Colonia Polanco Chapultepec, ...
# 15  (La Napoles, Calle 80 Sur, Getsemaní, UPZs de ...
# 16  (Zona de Juegos Infantiles "La Tapatía", Colon...

# %%
start = time.time()

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

df['coordenadas'] = df['direccion'].apply(lambda x:(x.latitude, x.longitude))

end = time.time()
elapsed = end-start
print(str(elapsed)+"seconds")
# Out:
# 0.0031464099884033203seconds
# <ipython-input-11-2ea759a99d37>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['coordenadas'] = df['direccion'].apply(lambda x:(x.latitude, x.longitude))

# %%
df.head()
# Out:
#                    nombre                                          direccion  \
# 0  Parque Masayoshi Ohira  (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 2       Parque Cuitláhuac  (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 3      Parque La Mexicana  (La Mexicana, Cuajimalpa de Morelos, Ciudad de...
# 4       Parque Cuitláhuac  (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 5  Parque Masayoshi Ohira  (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
#
#                                coordenadas
# 0        (19.35241215, -99.14215968176771)
# 2  (19.326969300000002, -99.0430968572247)
# 3         (19.3575338, -99.27044990929093)
# 4  (19.326969300000002, -99.0430968572247)
# 5        (19.35241215, -99.14215968176771)

# %%
latitud = []
longitud = []
for index, row in df.iterrows():
  coordenadas = row['coordenadas']
  latitud.append(coordenadas[0])
  longitud.append(coordenadas[1])

df['latitud'] = latitud
df['longitud'] = longitud
# Out:
# <ipython-input-13-76d506516bbe>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitud'] = latitud
# <ipython-input-13-76d506516bbe>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitud'] = longitud

# %%
df.head()
# Out:
#                    nombre                                          direccion  \
# 0  Parque Masayoshi Ohira  (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
# 2       Parque Cuitláhuac  (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 3      Parque La Mexicana  (La Mexicana, Cuajimalpa de Morelos, Ciudad de...
# 4       Parque Cuitláhuac  (Parque Cuitláhuac, Desarrollo Urbano Quetzalc...
# 5  Parque Masayoshi Ohira  (Parque Masayoshi Ohira, Coyoacán, Ciudad de M...
#
#                                coordenadas    latitud   longitud
# 0        (19.35241215, -99.14215968176771)  19.352412 -99.142160
# 2  (19.326969300000002, -99.0430968572247)  19.326969 -99.043097
# 3         (19.3575338, -99.27044990929093)  19.357534 -99.270450
# 4  (19.326969300000002, -99.0430968572247)  19.326969 -99.043097
# 5        (19.35241215, -99.14215968176771)  19.352412 -99.142160

# %%
df.to_csv('parques_cdmx.csv')

# %%
tamaño = len(df)
i=1

# %%
jsfile = ""
jsfile = "var parque = { 'type':'FeatureCollection', \n"
jsfile = jsfile + "'features': [ \n"

for index, row in df.iterrows():
  nombre = row['nombre']
  longitud = row['longitud']
  latitud = row['latitud']
  if i<tamaño:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}},\n"
    i+=1
  else:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}} \n]};"

# %%
print(jsfile)
# Out:
# var parque = { 'type':'FeatureCollection',
# 'features': [
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Masayoshi Ohira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.14215968176771,19.35241215]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Cuitláhuac'},
#  'geometry': {'type':'Point', 'coordinates':[-99.0430968572247,19.326969300000002]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque La Mexicana'},
#  'geometry': {'type':'Point', 'coordinates':[-99.27044990929093,19.3575338]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Cuitláhuac'},
#  'geometry': {'type':'Point', 'coordinates':[-99.0430968572247,19.326969300000002]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Masayoshi Ohira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.14215968176771,19.35241215]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Luis G. Urbina (Parque Hundido)'},
#  'geometry': {'type':'Point', 'coordinates':[-99.17931325527846,19.37819005]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Tezozómoc'},
#  'geometry': {'type':'Point', 'coordinates':[-99.20963595761995,19.49971185]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Rufino Tamayo'},
#  'geometry': {'type':'Point', 'coordinates':[-100.32822742420515,25.6445273]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Lira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18968715277619,19.405764599999998]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque México'},
#  'geometry': {'type':'Point', 'coordinates':[-99.16922145932,19.41232825]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Bicentenario'},
#  'geometry': {'type':'Point', 'coordinates':[-71.6141137,-35.4130059]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque de los Venados'},
#  'geometry': {'type':'Point', 'coordinates':[-99.1587787,19.3706451]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Lincoln'},
#  'geometry': {'type':'Point', 'coordinates':[-99.19708230885169,19.42952905]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Alameda Nápoles'},
#  'geometry': {'type':'Point', 'coordinates':[-74.2061331,4.6112524]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque La Tapatía'},
#  'geometry': {'type':'Point', 'coordinates':[-99.19710779681623,19.4183747]}}
# ]};

# %%
lista_museos = []

# %%
url = 'https://sic.cultura.gob.mx/lista.php?table=museo&estado_id=9&municipio_id=-1'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

for link in soup.find_all('a'):
  nombre = link.text.strip()
  nombre = nombre.lower()
  if 'museo' in nombre:
    lista_museos.append(nombre)

# %%
lista_museos
# Out:
# ['museos',
#  'museos',
#  'museos',
#  'museo tezozómoc',
#  'museo de  azcapotzalco',
#  'museo nacional de las intervenciones',
#  'universum museo de las ciencias',
#  'museo del retrato hablado (cerrado por remodelación)',
#  'museo universitario de ciencias y artes (muca)',
#  'museo casa de león trotsky',
#  'museo del ejército y fuerza aérea',
#  'museo nacional de la acuarela alfredo guati rojo',
#  'museo frida kahlo',
#  'museo de anatomopatología veterinaria manuel h. sarvide',
#  'museo anahuacalli',
#  'pabellón nacional de la biodiversidad. museo interactivo y espacio de investigación',
#  'museo universitario de arte contemporáneo (muac)',
#  'museo nacional de culturas populares',
#  'museo centro cultural nacional pedro infante',
#  'museo bicentenario del ex convento del desierto de los leones',
#  'museo miguel hidalgo',
#  'museo de la basílica de guadalupe',
#  'museo de los ferrocarrileros',
#  'museo de geología y paleontología',
#  'el museo de historia del mormonismo en méxico',
#  'museo de figuras de cera de la villa',
#  'museo diablos: una historia incomparable',
#  'museo cabeza de juárez',
#  'museo de las culturas pasión por iztapalapa',
#  'museo-observatorio interactivo de hundimiento y fracturamiento (oihfra)',
#  'museo fuego nuevo',
#  'museo comunitario de san miguel teotongo',
#  'museo barco utopía',
#  'museo del servicio de transportes eléctricos',
#  'museo regional altepepialcalli',
#  'centro cultural isidro fabela-museo casa del risco',
#  'museo nacional de la vivienda (munavi)',
#  'museo soumaya, plaza loreto',
#  'museo del axolote',
#  'museo de arte alvar y carmen t. de carrillo gil',
#  'museo interactivo de la guardia nacional (cerrado temporalmente)',
#  'museo de el carmen',
#  'museo casa estudio diego rivera y frida kahlo',
#  'museo cielito lindo',
#  'museo regional comunitario cuitláhuac',
#  'museo andrés quintana roo',
#  'museo tomás medina villarruel',
#  'museo de la casa de cultura de la uaeméx',
#  'museo casa estudio federico & elsa',
#  'museo del tiempo tlalpan (cerrado temporalmente)',
#  'museo del heroico colegio militar',
#  'museo de sitio de cuicuilco',
#  'museo dolores olmedo (cerrado temporalmente, próxima apertura)',
#  'museo arqueológico de xochimilco',
#  'museo flor de chinampas (chinampaxochitl)',
#  'museo estelar',
#  'museo de sitio de la zona arqueológica de mixcoac',
#  'museo del metro',
#  'museo polyforum siqueiros (cerrado por remodelación)',
#  'casa museo benita galeana',
#  'museo de arte en azúcar méxico',
#  'museo numismático nacional',
#  'museo recinto homenaje a cuauhtémoc',
#  'museo de tecpan (cerrado por remodelación)',
#  'museo banco de méxico',
#  'museo del perfume mupe (cerrado temporalmente)',
#  'museo josé luis cuevas',
#  'museo experimental el eco',
#  'museo casa de la memoria indómita',
#  'museo de la luz',
#  'museo nacional de la revolución',
#  'museo del bicentenario',
#  'museo universitario del chopo',
#  'museo manuel tolsá',
#  'museo galería nuestra cocina duque de herdez',
#  'museo del telégrafo',
#  'museo de geología',
#  'museo del pulque y las pulquerías',
#  'museo de sitio del antiguo hospital concepción béistegui',
#  'museo kaluz',
#  'museo ferrocarrilero víctor flores morales',
#  'museo del instituto cultural méxico israel',
#  'casa museo guillermo tovar de teresa',
#  'museo de la policía de la ciudad de méxico',
#  'museo de sitio san sebastián atzacoalco',
#  'museo de la charrería',
#  'museo del estanquillo',
#  'museo memoria y tolerancia',
#  'museo de lo increíble ripley',
#  'museo xaltilolli, centro de interpretación',
#  'museo centro de la imagen',
#  'museo del padre pro',
#  'museo de arte popular',
#  'museo de sitio de tlatelolco caja de agua',
#  'museo de las constituciones',
#  'museo art toys',
#  'museo unam hoy',
#  'museo ramón lópez velarde',
#  'museo interactivo de la bolsa mexicana de valores',
#  'museo vizcaínas',
#  'museo mural diego rivera',
#  'museo del ejército y fuerza aérea mexicanos de bethlemitas (cerrado temporalmente)',
#  'museo de la mujer',
#  'museo del objeto del objeto (modo)',
#  'museo salón de cabildos del antiguo palacio del ayuntamiento',
#  'museo panteón de san fernando',
#  'museo interactivo de economía (mide)',
#  'museo universitario de ciencias y artes (muca) roma',
#  'museo del tequila y el mezcal (mutem)',
#  'museo casa de las mil muñecas',
#  'museo del calzado el borceguí',
#  'museo nacional de san carlos',
#  'museo de la cancillería',
#  'museo de sitio',
#  'museo franz mayer',
#  'museo indígena, antigua aduana de peralvillo',
#  'museo de la ciudad de méxico',
#  'museo de patología hospital general de méxico eduardo liceaga',
#  'museo de la inquisición',
#  'museo del templo mayor',
#  'museo nacional de las culturas del mundo',
#  'museo del palacio de bellas artes',
#  'museo de sitio de la sep',
#  'museo la ciudad y la torre a través de los siglos',
#  'mundo chocolate museo (mucho)',
#  'museo nacional de la estampa (munae)',
#  'museo nacional de arte (munal)',
#  'museo casa de carranza',
#  'museo mexicano del diseño (mumedi)',
#  'museo foro valparaíso',
#  'museo de la caricatura',
#  'museo de arte de la shcp',
#  'museo de sitio del centro cultural casa talavera',
#  'museo archivo de la fotografía (maf)',
#  'museo del juguete antiguo méxico',
#  'museo de cera de la ciudad de méxico',
#  'museo nacional de arquitectura',
#  'museo postal y filatélico',
#  'museo soumaya, plaza carso',
#  'museo de la brigada de fusileros paracaidistas',
#  'museo tamayo arte contemporáneo',
#  'anfibium: museo del axolote y centro de conservación de anfibios',
#  'museo nacional de historia castillo de chapultepec',
#  'maná, museo de la biblia',
#  'museo de historia natural y cultura ambiental',
#  'museo casa presidencial lázaro cárdenas',
#  'papalote museo del niño chapultepec',
#  'museo casa de la bola',
#  'museo nacional de antropología (mna)',
#  'galería de historia, museo del caracol',
#  'museo de arte moderno (mam)',
#  'museo nacional de la cartografía',
#  'museo de sitio y centro de visitantes del bosque de chapultepec',
#  'museo del centenario del ejército mexicano',
#  'museo de geofísica',
#  'museo jumex',
#  'museo de caballería',
#  'museo legislativo los sentimientos de la nación']

# %%
geolocator = Nominatim(user_agent='cctmexico')
df = pd.DataFrame({'nombre':lista_museos})

# %%
df
# Out:
#                                               nombre
# 0                                             museos
# 1                                             museos
# 2                                             museos
# 3                                    museo tezozómoc
# 4                             museo de  azcapotzalco
# ..                                               ...
# 153       museo del centenario del ejército mexicano
# 154                               museo de geofísica
# 155                                      museo jumex
# 156                              museo de caballería
# 157  museo legislativo los sentimientos de la nación
#
# [158 rows x 1 columns]

# %%
df = df.sample(20)

# %%
df
# Out:
#                                                 nombre
# 156                                museo de caballería
# 143                           maná, museo de la biblia
# 110                      museo del calzado el borceguí
# 130                             museo de la caricatura
# 147                              museo casa de la bola
# 16    museo universitario de arte contemporáneo (muac)
# 78   museo de sitio del antiguo hospital concepción...
# 109                      museo casa de las mil muñecas
# 100                           museo mural diego rivera
# 27                              museo cabeza de juárez
# 51                         museo de sitio de cuicuilco
# 137                          museo postal y filatélico
# 111                       museo nacional de san carlos
# 67                           museo experimental el eco
# 64                               museo banco de méxico
# 4                               museo de  azcapotzalco
# 75                                 museo del telégrafo
# 6                      universum museo de las ciencias
# 96                                      museo unam hoy
# 107  museo universitario de ciencias y artes (muca)...

# %%
import time
start = time.time()

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

df['direccion'] = df['nombre'].apply(geocode)

end = time.time()
elapsed = end-start
print(str(elapsed)+"seconds")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=museo+banco+de+m%C3%A9xico&format=json&limit=1
# 20.702160835266113seconds

# %%
df
# Out:
#                                                 nombre  \
# 156                                museo de caballería
# 143                           maná, museo de la biblia
# 110                      museo del calzado el borceguí
# 130                             museo de la caricatura
# 147                              museo casa de la bola
# 16    museo universitario de arte contemporáneo (muac)
# 78   museo de sitio del antiguo hospital concepción...
# 109                      museo casa de las mil muñecas
# 100                           museo mural diego rivera
# 27                              museo cabeza de juárez
# 51                         museo de sitio de cuicuilco
# 137                          museo postal y filatélico
# 111                       museo nacional de san carlos
# 67                           museo experimental el eco
# 64                               museo banco de méxico
# 4                               museo de  azcapotzalco
# 75                                 museo del telégrafo
# 6                      universum museo de las ciencias
# 96                                      museo unam hoy
# 107  museo universitario de ciencias y artes (muca)...
#
#                                              direccion
# 156  (Real Maestranza de Caballería de Zaragoza, Ca...
# 143                                               None
# 110  (Museo del Calzado El Borceguí, 27, Calle Simó...
# 130  (Museo de la Caricatura, Calle Donceles, Centr...
# 147  (Museo Casa de la Bola, Avenida Parque Lira, C...
# 16   (Museo Universitario de Arte Contemporáneo (MU...
# 78                                                None
# 109                                               None
# 100  (Museo Mural Diego Rivera, Calle Cristóbal Col...
# 27   (Museo Cabeza de Juárez, Calle Juan Cristomo B...
# 51   (Museo de Sitio Cuicuilco, Rampa Poniente, Col...
# 137  (Museo Postal, Telegráfico y Filatélico, Juan ...
# 111  (Museo Nacional de San Carlos, Calle Miguel Ra...
# 67   (museo experimental el eco, 43, Calle James Su...
# 64                                                None
# 4                                                 None
# 75   (Museo del Telégrafo, Calle Filomeno Mata, Cen...
# 6                                                 None
# 96   (Museo UNAM Hoy, 2, Moneda, Centro, Cuauhtémoc...
# 107                                               None

# %%
df = df.dropna()
df
# Out:
#                                                nombre  \
# 156                               museo de caballería
# 110                     museo del calzado el borceguí
# 130                            museo de la caricatura
# 147                             museo casa de la bola
# 16   museo universitario de arte contemporáneo (muac)
# 100                          museo mural diego rivera
# 27                             museo cabeza de juárez
# 51                        museo de sitio de cuicuilco
# 137                         museo postal y filatélico
# 111                      museo nacional de san carlos
# 67                          museo experimental el eco
# 75                                museo del telégrafo
# 96                                     museo unam hoy
#
#                                              direccion
# 156  (Real Maestranza de Caballería de Zaragoza, Ca...
# 110  (Museo del Calzado El Borceguí, 27, Calle Simó...
# 130  (Museo de la Caricatura, Calle Donceles, Centr...
# 147  (Museo Casa de la Bola, Avenida Parque Lira, C...
# 16   (Museo Universitario de Arte Contemporáneo (MU...
# 100  (Museo Mural Diego Rivera, Calle Cristóbal Col...
# 27   (Museo Cabeza de Juárez, Calle Juan Cristomo B...
# 51   (Museo de Sitio Cuicuilco, Rampa Poniente, Col...
# 137  (Museo Postal, Telegráfico y Filatélico, Juan ...
# 111  (Museo Nacional de San Carlos, Calle Miguel Ra...
# 67   (museo experimental el eco, 43, Calle James Su...
# 75   (Museo del Telégrafo, Calle Filomeno Mata, Cen...
# 96   (Museo UNAM Hoy, 2, Moneda, Centro, Cuauhtémoc...

# %%
import time
start = time.time()

from geopy.extra.rate_limiter import RateLimiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

df['coordenadas'] = df['direccion'].apply(lambda x:(x.latitude, x.longitude))

end = time.time()
elapsed = end-start
print(str(elapsed)+"seconds")
# Out:
# 0.003482818603515625seconds
# <ipython-input-31-41673ee661c0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['coordenadas'] = df['direccion'].apply(lambda x:(x.latitude, x.longitude))

# %%
df.head()
# Out:
#                                                nombre  \
# 156                               museo de caballería
# 110                     museo del calzado el borceguí
# 130                            museo de la caricatura
# 147                             museo casa de la bola
# 16   museo universitario de arte contemporáneo (muac)
#
#                                              direccion  \
# 156  (Real Maestranza de Caballería de Zaragoza, Ca...
# 110  (Museo del Calzado El Borceguí, 27, Calle Simó...
# 130  (Museo de la Caricatura, Calle Donceles, Centr...
# 147  (Museo Casa de la Bola, Avenida Parque Lira, C...
# 16   (Museo Universitario de Arte Contemporáneo (MU...
#
#                                    coordenadas
# 156  (41.654535949999996, -0.8765572669352024)
# 110                  (19.4331077, -99.1385286)
# 130          (19.43563575, -99.13265889416724)
# 147           (19.4047974, -99.18865833975357)
# 16           (19.31478065, -99.18543814020602)

# %%
latitud = []
longitud = []
for index, row in df.iterrows():
  coordenadas = row['coordenadas']
  latitud.append(coordenadas[0])
  longitud.append(coordenadas[1])

df['latitud'] = latitud
df['longitud'] = longitud
# Out:
# <ipython-input-33-76d506516bbe>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitud'] = latitud
# <ipython-input-33-76d506516bbe>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitud'] = longitud

# %%
df.head()
# Out:
#                                                nombre  \
# 156                               museo de caballería
# 110                     museo del calzado el borceguí
# 130                            museo de la caricatura
# 147                             museo casa de la bola
# 16   museo universitario de arte contemporáneo (muac)
#
#                                              direccion  \
# 156  (Real Maestranza de Caballería de Zaragoza, Ca...
# 110  (Museo del Calzado El Borceguí, 27, Calle Simó...
# 130  (Museo de la Caricatura, Calle Donceles, Centr...
# 147  (Museo Casa de la Bola, Avenida Parque Lira, C...
# 16   (Museo Universitario de Arte Contemporáneo (MU...
#
#                                    coordenadas    latitud   longitud
# 156  (41.654535949999996, -0.8765572669352024)  41.654536  -0.876557
# 110                  (19.4331077, -99.1385286)  19.433108 -99.138529
# 130          (19.43563575, -99.13265889416724)  19.435636 -99.132659
# 147           (19.4047974, -99.18865833975357)  19.404797 -99.188658
# 16           (19.31478065, -99.18543814020602)  19.314781 -99.185438

# %%
df.to_csv('museos_cdmx.csv')

# %%
tamaño = len(df)
i=1

# %%
#jsfile = "" seguimos agregando contenido al archivo anterior. Esto es porque el mapa utiliza como fuente un solo archivo
jsfile = jsfile + "\n var museo = { 'type':'FeatureCollection', \n"
jsfile = jsfile + "'features': [ \n"

for index, row in df.iterrows():
  nombre = row['nombre']
  longitud = row['longitud']
  latitud = row['latitud']
  if i<tamaño:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}},\n"
    i+=1
  else:
    jsfile = jsfile +" {'type':'Feature', \n 'properties':{'nombre':'"+nombre+"'}, \n 'geometry': {'type':'Point', 'coordinates':["+str(longitud)+","+str(latitud)+"]}} \n]};"

# %%
print(jsfile)
# Out:
# var parque = { 'type':'FeatureCollection',
# 'features': [
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Masayoshi Ohira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.14215968176771,19.35241215]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Cuitláhuac'},
#  'geometry': {'type':'Point', 'coordinates':[-99.0430968572247,19.326969300000002]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque La Mexicana'},
#  'geometry': {'type':'Point', 'coordinates':[-99.27044990929093,19.3575338]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Cuitláhuac'},
#  'geometry': {'type':'Point', 'coordinates':[-99.0430968572247,19.326969300000002]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Masayoshi Ohira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.14215968176771,19.35241215]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Luis G. Urbina (Parque Hundido)'},
#  'geometry': {'type':'Point', 'coordinates':[-99.17931325527846,19.37819005]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Tezozómoc'},
#  'geometry': {'type':'Point', 'coordinates':[-99.20963595761995,19.49971185]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Rufino Tamayo'},
#  'geometry': {'type':'Point', 'coordinates':[-100.32822742420515,25.6445273]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Lira'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18968715277619,19.405764599999998]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque México'},
#  'geometry': {'type':'Point', 'coordinates':[-99.16922145932,19.41232825]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Bicentenario'},
#  'geometry': {'type':'Point', 'coordinates':[-71.6141137,-35.4130059]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque de los Venados'},
#  'geometry': {'type':'Point', 'coordinates':[-99.1587787,19.3706451]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Lincoln'},
#  'geometry': {'type':'Point', 'coordinates':[-99.19708230885169,19.42952905]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque Alameda Nápoles'},
#  'geometry': {'type':'Point', 'coordinates':[-74.2061331,4.6112524]}},
#  {'type':'Feature',
#  'properties':{'nombre':'Parque La Tapatía'},
#  'geometry': {'type':'Point', 'coordinates':[-99.19710779681623,19.4183747]}}
# ]};
#  var museo = { 'type':'FeatureCollection',
# 'features': [
#  {'type':'Feature',
#  'properties':{'nombre':'museo de el carmen'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18972239336588,19.345041600000002]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo casa de león trotsky'},
#  'geometry': {'type':'Point', 'coordinates':[-99.15933543882605,19.3575411]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo universitario de arte contemporáneo (muac)'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18543814020602,19.31478065]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo del objeto del objeto (modo)'},
#  'geometry': {'type':'Point', 'coordinates':[-99.1590699,19.4202149]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo de geofísica'},
#  'geometry': {'type':'Point', 'coordinates':[-57.9331099,-34.908339]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo casa de la bola'},
#  'geometry': {'type':'Point', 'coordinates':[-99.18865833975357,19.4047974]}},
#  {'type':'Feature',
#  'properties':{'nombre':'museo del bicentenario'},
#  'geometry': {'type':'Point', 'coordinates':[-58.36956384453619,-34.6081996]}}
# ]};

# %%
with open('datos.js', 'a') as archivo:
  archivo.write(jsfile)
archivo.close()
